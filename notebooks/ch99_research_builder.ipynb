# %% [markdown]
# # Research Builder — 自分の音声研究を設計する
#
# 各Labから自分の研究計画へ移るためのCapstoneです。

# %% [markdown]
# ## 1. Research Question
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 2. Background
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 3. Hypothesis
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 4. Independent Variables
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 5. Dependent Variables
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 6. Stimuli
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 7. Participants
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 8. Experimental Design
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %%
from pathlib import Path
import sys
sys.path.insert(0,'../src')
from phonlab import *
setup(2027)
trials=make_trial_list(99,n_repetitions=4)
trials.head()

# %% [markdown]
# ## 9. Pilot
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 10. Data Collection
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 11. Data Cleaning
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 12. Analysis
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %%
ANALYSIS_PLAN={'outcome':None,'predictors':[],'exclusions':[],'claim_criterion':None}
ANALYSIS_PLAN

# %% [markdown]
# ## 13. Visualization
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 14. Results
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 15. Interpretation
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 16. Limitations
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## 17. Follow-up Study
#
# 計画・根拠・判断基準を記入し、未決定事項は未決定と明記します。

# %% [markdown]
# ## Ethics and licensing gate
#
# 倫理審査・同意・録音許諾・匿名化・保管・二次利用・削除・ライセンスを確認します。

# %%
import json
plan={'status':'DRAFT — NOT REGISTERED','seed':2027,'analysis_plan':ANALYSIS_PLAN}
Path('research_plan.json').write_text(json.dumps(plan,ensure_ascii=False,indent=2),encoding='utf-8')
